# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# !pip install ultralytics
# !pip install torch-geometric
# !pip install opencv-python
# !pip install networkx
# !pip install numpy
# !pip install torch-geometric-temporal
# !pip install --upgrade torch-geometric

# %%
# !pip install torch-geometric==2.0.4 torch-scatter torch-sparse torch-cluster torch-spline-conv -f https://data.pyg.org/whl/torch-2.0.1+cu124.html

# %% [markdown]
# Dynamic GNNs Code

# %%
import cv2
import torch
from ultralytics import YOLO
import time
import numpy as np
from torch_geometric.nn import GCNConv
import os
import networkx as nx

# Set CUDA Launch Blocking for debugging
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# Set device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Load the YOLOv11 Model on GPU if available
model = YOLO("E:/paper_code/small_object_detection/runs/detect/train4/weights/best.pt").to(device)

# Set up the Video Capture Object (for video file or webcam)
cap = cv2.VideoCapture("E:/paper_code/small_object_detection/traffic_1.mp4")  # Use 0 for webcam

# Define a Dynamic GNN Model (DGNN)
class DGNNTracker(torch.nn.Module):
    def __init__(self):
        super(DGNNTracker, self).__init__()
        self.conv1 = GCNConv(4, 16)
        self.conv2 = GCNConv(16, 8)
    
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x

# Initialize DGNN model on the appropriate device
dgnn_model = DGNNTracker().to(device)
dgnn_model.eval()

# Initialize Graph to store edges and node features dynamically
G = nx.Graph()  # Initialize the graph here

# Store object previous positions and velocities
object_previous_positions = {}
object_velocities = {}

# Define the region of interest (ROI) for tracking vehicles
def define_roi(frame):
    frame_width = frame.shape[1]  # Frame width (number of pixels)
    frame_height = frame.shape[0]  # Frame height (number of pixels)

    # Define the ROI as the whole frame or divide it into two halves
    # Tracking in both the left and right halves of the frame
    roi_left = 0
    roi_top = 0
    roi_right = frame_width  # Whole width
    roi_bottom = frame_height  # Whole height
    
    return roi_left, roi_top, roi_right, roi_bottom

# Post-process bounding boxes to avoid overly large boxes
def refine_bounding_box(box, min_width=20, min_height=20):
    x_min, y_min, x_max, y_max = box
    width = x_max - x_min
    height = y_max - y_min

    # Apply constraints on minimum width and height
    if width < min_width:
        x_max = x_min + min_width
    if height < min_height:
        y_max = y_min + min_height

    return [x_min, y_min, x_max, y_max]

# Loop through Video Frames
while cap.isOpened():
    start_time = time.time()
    ret, frame = cap.read()

    if ret:
        # Define the region of interest (ROI) for tracking vehicles
        roi_left, roi_top, roi_right, roi_bottom = define_roi(frame)

        # Visualize the ROI on the frame
        cv2.rectangle(frame, (int(roi_left), int(roi_top)), (int(roi_right), int(roi_bottom)), (0, 255, 0), 2)

        # Run YOLOv11 detection
        results = model.track(frame, persist=True, conf=0.5)  # Adjust confidence threshold here (0.5)

        # Ensure results are not empty
        if results and results[0].boxes is not None and len(results[0].boxes) > 0:
            detections = results[0].boxes.xyxy.cpu().numpy()  # Extract bounding boxes

            # Extract node features (center x, center y, width, height)
            nodes = []
            for i, box in enumerate(detections):
                x_min, y_min, x_max, y_max = box
                # Refine the bounding box to prevent it from being too large
                refined_box = refine_bounding_box([x_min, y_min, x_max, y_max])

                center_x = (refined_box[0] + refined_box[2]) / 2
                center_y = (refined_box[1] + refined_box[3]) / 2
                width = refined_box[2] - refined_box[0]
                height = refined_box[3] - refined_box[1]

                # Filter nodes based on their position within the ROI
                if roi_left < center_x < roi_right and roi_top < center_y < roi_bottom:
                    nodes.append([center_x, center_y, width, height])

                # Track object velocity (difference in position from previous frame)
                if i in object_previous_positions:
                    prev_position = object_previous_positions[i]
                    velocity = np.array([center_x, center_y]) - np.array(prev_position)
                    object_velocities[i] = velocity
                else:
                    object_velocities[i] = np.array([0, 0])  # Initial velocity is zero

                # Update the previous position for the current object
                object_previous_positions[i] = [center_x, center_y]

            # Create node feature tensor and edge index tensor
            if len(nodes) > 0:
                x = torch.tensor(nodes, dtype=torch.float).to(device)  # Ensure tensor is on the correct device
                
                # Edge index (dynamic addition/removal of edges)
                edges_to_remove = []
                edges_to_add = []
                
                # Iterate over all existing edges to decide which to remove (objects no longer interacting)
                for i in list(G.nodes):
                    if i >= len(nodes):  # Remove objects that have disappeared
                        edges_to_remove.extend(list(G.edges(i)))
                
                # Remove disconnected edges safely (check if edge exists before removal)
                for edge in edges_to_remove:
                    if G.has_edge(*edge):  # Check if the edge still exists
                        G.remove_edge(*edge)

                # Add new edges based on distance, velocity, and other criteria
                for i in range(len(nodes)):
                    for j in range(i + 1, len(nodes)):
                        dist = np.linalg.norm(np.array(nodes[i][:2]) - np.array(nodes[j][:2]))
                        velocity_magnitude = np.linalg.norm(object_velocities[i] - object_velocities[j])

                        # Add edge if within distance and velocity threshold
                        if dist < 50 or velocity_magnitude < 10:  # Adjust thresholds as needed
                            G.add_edge(i, j)

                # Convert edge list to edge_index tensor
                edges = list(G.edges)
                if len(edges) > 0:
                    edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous().to(device)  # Ensure edge_index is on the correct device
                    
                    # Use DGNN model to refine associations
                    with torch.no_grad():
                        out = dgnn_model(x, edge_index)  # Process graph

                # Visualize results with slimmer bounding boxes and smaller font
                annotated_frame = results[0].plot()
                for i, (cx, cy, w, h) in enumerate(nodes):
                    # Draw a slim bounding box
                    cv2.rectangle(
                        annotated_frame,
                        (int(cx - w / 2), int(cy - h / 2)),
                        (int(cx + w / 2), int(cy + h / 2)),
                        (0, 0, 255),
                        1  # Slimmer line thickness
                    )
                    # Draw a small circle for the center
                    cv2.circle(annotated_frame, (int(cx), int(cy)), 3, (0, 255, 0), -1)
                    
                # Display FPS with smaller font
                end_time = time.time()
                fps = 1 / (end_time - start_time)
                cv2.putText(
                    annotated_frame,
                    f"FPS: {fps:.2f}",
                    (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5,  # Smaller font size
                    (0, 255, 0),
                    1  # Thinner font weight
                )
                
                # Show the frame
                cv2.imshow("YOLOv11 Tracking with DGNN", annotated_frame)
        else:
            print("No detections in this frame.")
        
        # Break the loop if 'q' key is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        print("End of video or error in capturing frames.")
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# Using device: cuda
#
# 0: 192x288 3 Cars, 6 Cngs, 1 Covered-Van, 1 Motor-Cycle, 75.3ms
# Speed: 6.6ms preprocess, 75.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 6 Cngs, 1 Covered-Van, 1 Motor-Cycle, 96.7ms
# Speed: 2.3ms preprocess, 96.7ms inference, 6.3ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Covered-Van, 55.4ms
# Speed: 2.5ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 64.0ms
# Speed: 0.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 4 Cngs, 1 Covered-Van, 1 Motor-Cycle, 96.2ms
# Speed: 15.9ms preprocess, 96.2ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 6 Cngs, 1 Covered-Van, 90.7ms
# Speed: 3.1ms preprocess, 90.7ms inference, 7.1ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 6 Cngs, 1 Motor-Cycle, 47.9ms
# Speed: 12.9ms preprocess, 47.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Person, 71.8ms
# Speed: 0.0ms preprocess, 71.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 67.6ms
# Speed: 17.3ms preprocess, 67.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 5 Cngs, 1 Covered-Van, 1 Motor-Cycle, 97.4ms
# Speed: 0.0ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 47.3ms
# Speed: 3.2ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 5 Cngs, 1 Covered-Van, 1 Motor-Cycle, 83.0ms
# Speed: 0.0ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 5 Cngs, 1 Covered-Van, 1 Motor-Cycle, 81.7ms
# Speed: 0.0ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 4 Cngs, 1 Covered-Van, 1 Motor-Cycle, 64.4ms
# Speed: 0.0ms preprocess, 64.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 4 Cngs, 1 Covered-Van, 1 Motor-Cycle, 63.7ms
# Speed: 0.0ms preprocess, 63.7ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 5 Cngs, 1 Covered-Van, 1 Motor-Cycle, 68.7ms
# Speed: 0.0ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 57.0ms
# Speed: 0.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 91.5ms
# Speed: 0.0ms preprocess, 91.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 3 Cngs, 1 Covered-Van, 2 Motor-Cycles, 62.3ms
# Speed: 0.0ms preprocess, 62.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 5 Cngs, 1 Covered-Van, 1 Motor-Cycle, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 5 Cngs, 1 Covered-Van, 1 Motor-Cycle, 85.1ms
# Speed: 0.0ms preprocess, 85.1ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 4 Cngs, 2 Covered-Vans, 78.9ms
# Speed: 2.0ms preprocess, 78.9ms inference, 16.3ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 4 Cngs, 1 Covered-Van, 1 Person, 81.9ms
# Speed: 15.8ms preprocess, 81.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 4 Cngs, 2 Covered-Vans, 1 Motor-Cycle, 1 Person, 63.7ms
# Speed: 0.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 4 Cngs, 2 Covered-Vans, 1 Person, 46.9ms
# Speed: 4.2ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 95.0ms
# Speed: 8.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 4 Cngs, 1 Covered-Van, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 6 Cngs, 2 Covered-Vans, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 4 Cngs, 1 Covered-Van, 1 Motor-Cycle, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 83.4ms
# Speed: 0.0ms preprocess, 83.4ms inference, 13.9ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 4 Cngs, 1 Covered-Van, 1 Person, 108.6ms
# Speed: 0.0ms preprocess, 108.6ms inference, 2.4ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 1 Covered-Van, 79.8ms
# Speed: 0.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 4 Cngs, 1 Covered-Van, 1 Person, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 5 Cngs, 2 Covered-Vans, 1 Person, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 6 Cngs, 1 Covered-Van, 1 Person, 53.2ms
# Speed: 10.6ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 4 Cngs, 2 Covered-Vans, 1 Person, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Covered-Van, 47.4ms
# Speed: 4.3ms preprocess, 47.4ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 19.8ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 82.4ms
# Speed: 0.0ms preprocess, 82.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 1 Covered-Van, 78.8ms
# Speed: 0.0ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 3 Cngs, 1 Covered-Van, 65.0ms
# Speed: 0.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 1 Covered-Van, 80.0ms
# Speed: 0.0ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 2 Cngs, 1 Covered-Van, 94.4ms
# Speed: 12.5ms preprocess, 94.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 1 Covered-Van, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 2 Cngs, 47.0ms
# Speed: 0.0ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 54.5ms
# Speed: 0.0ms preprocess, 54.5ms inference, 15.9ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 64.3ms
# Speed: 8.0ms preprocess, 64.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 15.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 2 Cngs, 78.7ms
# Speed: 0.0ms preprocess, 78.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 95.6ms
# Speed: 9.5ms preprocess, 95.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 63.5ms
# Speed: 0.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 94.5ms
# Speed: 0.0ms preprocess, 94.5ms inference, 7.5ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 63.5ms
# Speed: 1.7ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 46.9ms
# Speed: 6.8ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 62.0ms
# Speed: 0.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 94.3ms
# Speed: 0.0ms preprocess, 94.3ms inference, 15.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 63.3ms
# Speed: 0.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Cng, 49.8ms
# Speed: 12.6ms preprocess, 49.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 52.1ms
# Speed: 0.0ms preprocess, 52.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Cng, 60.0ms
# Speed: 0.0ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 61.4ms
# Speed: 0.0ms preprocess, 61.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 85.7ms
# Speed: 0.0ms preprocess, 85.7ms inference, 2.8ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 2 Cngs, 69.6ms
# Speed: 0.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 91.8ms
# Speed: 0.0ms preprocess, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 2 Cngs, 46.9ms
# Speed: 15.6ms preprocess, 46.9ms inference, 16.4ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 3 Cngs, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 90.7ms
# Speed: 5.7ms preprocess, 90.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 70.7ms
# Speed: 0.0ms preprocess, 70.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 95.1ms
# Speed: 7.2ms preprocess, 95.1ms inference, 16.2ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 73.5ms
# Speed: 0.0ms preprocess, 73.5ms inference, 6.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 47.0ms
# Speed: 8.8ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 64.0ms
# Speed: 0.8ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 2 Cngs, 1 Covered-Van, 64.4ms
# Speed: 17.1ms preprocess, 64.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 2 Cngs, 64.9ms
# Speed: 1.1ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 2 Cngs, 77.0ms
# Speed: 0.0ms preprocess, 77.0ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 2 Cngs, 79.2ms
# Speed: 10.3ms preprocess, 79.2ms inference, 16.2ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 2 Cngs, 1 Covered-Van, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 2 Cngs, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 2 Cngs, 49.7ms
# Speed: 7.9ms preprocess, 49.7ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 1 Covered-Van, 46.9ms
# Speed: 7.7ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 95.0ms
# Speed: 0.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 64.4ms
# Speed: 0.0ms preprocess, 64.4ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 2 Covered-Vans, 94.5ms
# Speed: 0.0ms preprocess, 94.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 52.9ms
# Speed: 0.0ms preprocess, 52.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 52.4ms
# Speed: 0.0ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 63.1ms
# Speed: 3.6ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 2 Covered-Vans, 58.2ms
# Speed: 0.9ms preprocess, 58.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 49.8ms
# Speed: 1.6ms preprocess, 49.8ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 80.8ms
# Speed: 0.0ms preprocess, 80.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 2 Covered-Vans, 88.9ms
# Speed: 0.0ms preprocess, 88.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 63.0ms
# Speed: 5.9ms preprocess, 63.0ms inference, 16.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 2 Covered-Vans, 48.3ms
# Speed: 15.8ms preprocess, 48.3ms inference, 16.2ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 2 Covered-Vans, 68.7ms
# Speed: 0.0ms preprocess, 68.7ms inference, 16.8ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 49.4ms
# Speed: 7.8ms preprocess, 49.4ms inference, 15.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 62.5ms
# Speed: 12.4ms preprocess, 62.5ms inference, 16.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 49.9ms
# Speed: 9.4ms preprocess, 49.9ms inference, 15.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 85.4ms
# Speed: 15.3ms preprocess, 85.4ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 1 Pick-Up, 97.2ms
# Speed: 0.0ms preprocess, 97.2ms inference, 16.2ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 69.5ms
# Speed: 0.0ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cngs, 1 Covered-Van, 65.1ms
# Speed: 0.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 1 Pick-Up, 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Covered-Van, 1 Motor-Cycle, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 46.9ms
# Speed: 2.6ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 1 Pick-Up, 49.0ms
# Speed: 14.5ms preprocess, 49.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 3 Covered-Vans, 63.7ms
# Speed: 0.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Covered-Vans, 1 Pick-Up, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 1 Pick-Up, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 64.9ms
# Speed: 15.3ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 78.0ms
# Speed: 0.0ms preprocess, 78.0ms inference, 5.1ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cngs, 1 Covered-Van, 94.8ms
# Speed: 0.0ms preprocess, 94.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 47.1ms
# Speed: 8.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cngs, 2 Covered-Vans, 46.9ms
# Speed: 3.3ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 1 Covered-Van, 78.3ms
# Speed: 0.0ms preprocess, 78.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 63.8ms
# Speed: 11.0ms preprocess, 63.8ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 3 Covered-Vans, 63.4ms
# Speed: 0.0ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Covered-Vans, 85.5ms
# Speed: 0.0ms preprocess, 85.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Covered-Vans, 52.5ms
# Speed: 0.0ms preprocess, 52.5ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Covered-Vans, 79.9ms
# Speed: 0.0ms preprocess, 79.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cngs, 2 Covered-Vans, 78.6ms
# Speed: 0.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 2 Covered-Vans, 1 Person, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 1 Person, 95.2ms
# Speed: 9.5ms preprocess, 95.2ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 2 Covered-Vans, 1 Person, 65.4ms
# Speed: 0.0ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Covered-Vans, 79.4ms
# Speed: 7.6ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cngs, 2 Covered-Vans, 53.7ms
# Speed: 12.1ms preprocess, 53.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 2 Covered-Vans, 103.3ms
# Speed: 0.0ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Covered-Vans, 62.7ms
# Speed: 10.1ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 2 Covered-Vans, 48.5ms
# Speed: 16.2ms preprocess, 48.5ms inference, 16.1ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 2 Covered-Vans, 74.1ms
# Speed: 0.0ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 2 Covered-Vans, 1 Person, 48.1ms
# Speed: 15.7ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Covered-Vans, 1 Person, 58.6ms
# Speed: 0.0ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Covered-Vans, 1 Person, 84.3ms
# Speed: 16.1ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Covered-Vans, 1 Person, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 3 Covered-Vans, 1 Person, 47.4ms
# Speed: 3.5ms preprocess, 47.4ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 3 Covered-Vans, 1 Person, 93.7ms
# Speed: 0.0ms preprocess, 93.7ms inference, 16.4ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 1 Person, 72.9ms
# Speed: 0.0ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Covered-Van, 1 Person, 53.2ms
# Speed: 6.7ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Person, 80.8ms
# Speed: 0.0ms preprocess, 80.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 1 Person, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 1 Person, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 2 Persons, 47.0ms
# Speed: 0.0ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 2 Persons, 106.2ms
# Speed: 0.0ms preprocess, 106.2ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Covered-Van, 1 Person, 47.3ms
# Speed: 4.8ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Person, 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 1 Person, 48.2ms
# Speed: 7.9ms preprocess, 48.2ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 1 Person, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Covered-Van, 1 Person, 70.6ms
# Speed: 0.0ms preprocess, 70.6ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 48.0ms
# Speed: 4.4ms preprocess, 48.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 63.9ms
# Speed: 6.4ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 98.7ms
# Speed: 0.0ms preprocess, 98.7ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Covered-Vans, 1 Person, 47.4ms
# Speed: 15.7ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Covered-Van, 74.2ms
# Speed: 0.0ms preprocess, 74.2ms inference, 1.3ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Covered-Van, 96.7ms
# Speed: 7.0ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Covered-Van, 103.8ms
# Speed: 0.0ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 48.2ms
# Speed: 2.9ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 2 Covered-Vans, 1 Person, 109.9ms
# Speed: 0.0ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 85.1ms
# Speed: 5.5ms preprocess, 85.1ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Covered-Vans, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Covered-Vans, 1 Person, 94.9ms
# Speed: 0.0ms preprocess, 94.9ms inference, 17.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Covered-Vans, 1 Motor-Cycle, 63.7ms
# Speed: 8.1ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Covered-Vans, 1 Person, 53.8ms
# Speed: 0.0ms preprocess, 53.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Covered-Van, 1 Person, 57.0ms
# Speed: 0.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 86.3ms
# Speed: 0.0ms preprocess, 86.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 2 Covered-Vans, 110.2ms
# Speed: 0.0ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Covered-Van, 48.5ms
# Speed: 16.0ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Covered-Van, 1 Motor-Cycle, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Motor-Cycle, 63.7ms
# Speed: 0.0ms preprocess, 63.7ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Covered-Van, 1 Person, 87.4ms
# Speed: 4.4ms preprocess, 87.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Motor-Cycle, 63.9ms
# Speed: 0.0ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 2 Motor-Cycles, 88.2ms
# Speed: 0.0ms preprocess, 88.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Covered-Van, 2 Motor-Cycles, 63.3ms
# Speed: 0.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Covered-Van, 2 Motor-Cycles, 63.8ms
# Speed: 5.1ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Motor-Cycle, 94.0ms
# Speed: 0.0ms preprocess, 94.0ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Person, 80.6ms
# Speed: 0.0ms preprocess, 80.6ms inference, 16.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Motor-Cycle, 1 Person, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 2 Persons, 95.4ms
# Speed: 15.6ms preprocess, 95.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 71.1ms
# Speed: 0.0ms preprocess, 71.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 109.5ms
# Speed: 0.0ms preprocess, 109.5ms inference, 17.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 47.4ms
# Speed: 4.9ms preprocess, 47.4ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 103.5ms
# Speed: 0.0ms preprocess, 103.5ms inference, 18.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 73.3ms
# Speed: 0.0ms preprocess, 73.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Motor-Cycle, 47.5ms
# Speed: 0.0ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Motor-Cycle, 80.0ms
# Speed: 0.0ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cngs, 1 Motor-Cycle, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 15.8ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 63.1ms
# Speed: 7.7ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Motor-Cycle, 1 Person, 48.0ms
# Speed: 0.0ms preprocess, 48.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Motor-Cycle, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 55.6ms
# Speed: 14.3ms preprocess, 55.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Motor-Cycle, 54.1ms
# Speed: 14.5ms preprocess, 54.1ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Motor-Cycle, 54.0ms
# Speed: 3.2ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Motor-Cycle, 72.2ms
# Speed: 0.0ms preprocess, 72.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 3 Cngs, 1 Motor-Cycle, 79.2ms
# Speed: 0.0ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Motor-Cycle, 65.7ms
# Speed: 5.0ms preprocess, 65.7ms inference, 18.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 4 Cngs, 1 Motor-Cycle, 71.8ms
# Speed: 0.0ms preprocess, 71.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 4 Cngs, 1 Motor-Cycle, 93.7ms
# Speed: 0.0ms preprocess, 93.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 4 Cngs, 1 Motor-Cycle, 100.6ms
# Speed: 0.0ms preprocess, 100.6ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 3 Cngs, 1 Motor-Cycle, 72.6ms
# Speed: 4.8ms preprocess, 72.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Motor-Cycle, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Person, 53.7ms
# Speed: 16.6ms preprocess, 53.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Person, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 4 Cngs, 1 Person, 68.0ms
# Speed: 0.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 1 Person, 106.8ms
# Speed: 0.0ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 1 Motor-Cycle, 1 Person, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 4 Cngs, 1 Person, 63.4ms
# Speed: 0.0ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Motor-Cycle, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.3ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 1 Covered-Van, 1 Person, 62.5ms
# Speed: 0.6ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 4 Cngs, 1 Covered-Van, 63.3ms
# Speed: 0.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 4 Cngs, 1 Covered-Van, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 104.9ms
# Speed: 0.0ms preprocess, 104.9ms inference, 4.2ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 4 Cngs, 1 Covered-Van, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 5 Cngs, 1 Covered-Van, 1 Motor-Cycle, 95.5ms
# Speed: 0.0ms preprocess, 95.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 96.0ms
# Speed: 0.0ms preprocess, 96.0ms inference, 16.1ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 4 Cngs, 1 Covered-Van, 1 Motor-Cycle, 96.2ms
# Speed: 0.0ms preprocess, 96.2ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 77.7ms
# Speed: 0.0ms preprocess, 77.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 74.1ms
# Speed: 0.0ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cngs, 2 Covered-Vans, 1 Motor-Cycle, 73.2ms
# Speed: 0.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 2 Covered-Vans, 1 Motor-Cycle, 1 Person, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 2 Covered-Vans, 1 Motor-Cycle, 1 Person, 94.3ms
# Speed: 0.0ms preprocess, 94.3ms inference, 17.3ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 2 Covered-Vans, 1 Motor-Cycle, 64.7ms
# Speed: 15.5ms preprocess, 64.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 4 Cngs, 2 Covered-Vans, 1 Motor-Cycle, 1 Person, 61.2ms
# Speed: 0.0ms preprocess, 61.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 16.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 65.3ms
# Speed: 3.9ms preprocess, 65.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 51.8ms
# Speed: 0.0ms preprocess, 51.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 94.4ms
# Speed: 0.0ms preprocess, 94.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Covered-Van, 1 Person, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Covered-Van, 1 Person, 69.2ms
# Speed: 16.8ms preprocess, 69.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 63.5ms
# Speed: 0.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Person, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Person, 94.6ms
# Speed: 0.0ms preprocess, 94.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 56.2ms
# Speed: 10.8ms preprocess, 56.2ms inference, 15.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 85.9ms
# Speed: 0.0ms preprocess, 85.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Covered-Van, 71.6ms
# Speed: 0.0ms preprocess, 71.6ms inference, 17.1ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 47.4ms
# Speed: 1.5ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 76.3ms
# Speed: 0.0ms preprocess, 76.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 5 Cngs, 1 Covered-Van, 48.2ms
# Speed: 15.8ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Covered-Van, 78.9ms
# Speed: 16.2ms preprocess, 78.9ms inference, 4.3ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Covered-Van, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 79.1ms
# Speed: 10.4ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 4 Cngs, 1 Covered-Van, 1 Person, 58.3ms
# Speed: 0.0ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 4 Cngs, 1 Covered-Van, 1 Person, 48.2ms
# Speed: 15.1ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 80.2ms
# Speed: 0.0ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 78.7ms
# Speed: 0.0ms preprocess, 78.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 47.7ms
# Speed: 0.8ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Covered-Van, 76.8ms
# Speed: 0.0ms preprocess, 76.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 47.9ms
# Speed: 5.9ms preprocess, 47.9ms inference, 16.1ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Covered-Van, 48.3ms
# Speed: 15.9ms preprocess, 48.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 102.5ms
# Speed: 0.0ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Person, 112.0ms
# Speed: 15.3ms preprocess, 112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 112.8ms
# Speed: 0.0ms preprocess, 112.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Person, 64.8ms
# Speed: 0.0ms preprocess, 64.8ms inference, 16.2ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 67.9ms
# Speed: 0.0ms preprocess, 67.9ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Person, 63.8ms
# Speed: 3.4ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 1 Person, 48.7ms
# Speed: 0.0ms preprocess, 48.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 1 Person, 56.6ms
# Speed: 0.0ms preprocess, 56.6ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cngs, 1 Covered-Van, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 79.4ms
# Speed: 0.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 1 Person, 56.0ms
# Speed: 9.1ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 3 Cngs, 1 Covered-Van, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 1 Covered-Van, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 1 Motor-Cycle, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cngs, 1 Covered-Van, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 1 Covered-Van, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 53.1ms
# Speed: 0.0ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Covered-Van, 2 Motor-Cycles, 82.7ms
# Speed: 0.0ms preprocess, 82.7ms inference, 3.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Covered-Van, 1 Motor-Cycle, 1 Person, 87.6ms
# Speed: 0.0ms preprocess, 87.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Covered-Van, 1 Person, 73.4ms
# Speed: 0.0ms preprocess, 73.4ms inference, 15.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Covered-Van, 1 Motor-Cycle, 1 Person, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Covered-Vans, 1 Motor-Cycle, 95.8ms
# Speed: 0.0ms preprocess, 95.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Covered-Vans, 2 Motor-Cycles, 78.0ms
# Speed: 0.0ms preprocess, 78.0ms inference, 16.8ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 2 Motor-Cycles, 59.6ms
# Speed: 0.0ms preprocess, 59.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 49.0ms
# Speed: 13.3ms preprocess, 49.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 16.2ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 2 Covered-Vans, 2 Persons, 64.2ms
# Speed: 8.6ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 2 Covered-Vans, 2 Persons, 65.0ms
# Speed: 0.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Covered-Van, 1 Person, 78.8ms
# Speed: 0.0ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 1 Person, 94.4ms
# Speed: 4.9ms preprocess, 94.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 68.6ms
# Speed: 0.0ms preprocess, 68.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Person, 98.5ms
# Speed: 0.0ms preprocess, 98.5ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Motor-Cycle, 79.4ms
# Speed: 0.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Motor-Cycle, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Motor-Cycle, 1 Person, 51.6ms
# Speed: 16.3ms preprocess, 51.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Person, 95.8ms
# Speed: 0.0ms preprocess, 95.8ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Person, 81.2ms
# Speed: 0.0ms preprocess, 81.2ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Motor-Cycle, 1 Person, 102.9ms
# Speed: 0.0ms preprocess, 102.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Persons, 57.4ms
# Speed: 0.0ms preprocess, 57.4ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Person, 63.2ms
# Speed: 9.2ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 48.0ms
# Speed: 2.5ms preprocess, 48.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 46.9ms
# Speed: 9.0ms preprocess, 46.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Motor-Cycle, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 2 Cngs, 63.3ms
# Speed: 0.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Person, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 60.6ms
# Speed: 0.0ms preprocess, 60.6ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Person, 61.9ms
# Speed: 0.0ms preprocess, 61.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Person, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 58.1ms
# Speed: 4.0ms preprocess, 58.1ms inference, 16.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Person, 52.0ms
# Speed: 9.9ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Person, 84.0ms
# Speed: 0.0ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Person, 110.0ms
# Speed: 0.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 78.4ms
# Speed: 0.0ms preprocess, 78.4ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Person, 52.8ms
# Speed: 0.0ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Motor-Cycle, 47.3ms
# Speed: 15.8ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Motor-Cycle, 79.0ms
# Speed: 0.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Person, 66.2ms
# Speed: 0.0ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Person, 69.2ms
# Speed: 0.0ms preprocess, 69.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 1 Person, 76.2ms
# Speed: 0.0ms preprocess, 76.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 3 Cngs, 1 Covered-Van, 1 Person, 49.7ms
# Speed: 1.9ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 2 Cngs, 1 Covered-Van, 1 Person, 48.3ms
# Speed: 4.9ms preprocess, 48.3ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 1 Person, 66.1ms
# Speed: 5.4ms preprocess, 66.1ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 2 Covered-Vans, 1 Person, 80.5ms
# Speed: 0.0ms preprocess, 80.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Person, 63.3ms
# Speed: 5.6ms preprocess, 63.3ms inference, 16.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Person, 92.0ms
# Speed: 4.6ms preprocess, 92.0ms inference, 8.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Covered-Van, 1 Person, 67.6ms
# Speed: 0.0ms preprocess, 67.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Covered-Van, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 77.8ms
# Speed: 12.7ms preprocess, 77.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 2 Covered-Vans, 95.3ms
# Speed: 16.5ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Covered-Van, 65.6ms
# Speed: 0.0ms preprocess, 65.6ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 2 Covered-Vans, 96.0ms
# Speed: 0.0ms preprocess, 96.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 2 Covered-Vans, 79.1ms
# Speed: 0.0ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 3 Covered-Vans, 93.7ms
# Speed: 0.0ms preprocess, 93.7ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 3 Covered-Vans, 46.9ms
# Speed: 15.6ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 2 Covered-Vans, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 3 Covered-Vans, 49.9ms
# Speed: 0.0ms preprocess, 49.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 1 Car, 1 Cng, 3 Covered-Vans, 74.7ms
# Speed: 16.6ms preprocess, 74.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 3 Covered-Vans, 77.1ms
# Speed: 0.0ms preprocess, 77.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 3 Covered-Vans, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 3 Covered-Vans, 64.1ms
# Speed: 15.6ms preprocess, 64.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 2 Covered-Vans, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 15.8ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 2 Covered-Vans, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 3 Covered-Vans, 69.6ms
# Speed: 1.2ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 3 Covered-Vans, 46.9ms
# Speed: 15.6ms preprocess, 46.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Cng, 3 Covered-Vans, 81.5ms
# Speed: 8.0ms preprocess, 81.5ms inference, 15.8ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Cng, 2 Covered-Vans, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 3 Covered-Vans, 78.8ms
# Speed: 0.0ms preprocess, 78.8ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Covered-Vans, 57.9ms
# Speed: 0.0ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 4 Covered-Vans, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Covered-Vans, 78.0ms
# Speed: 15.6ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Covered-Vans, 82.9ms
# Speed: 0.0ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 1 Covered-Van, 91.6ms
# Speed: 0.0ms preprocess, 91.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 3 Covered-Vans, 77.5ms
# Speed: 1.5ms preprocess, 77.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 3 Covered-Vans, 70.0ms
# Speed: 5.5ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Covered-Vans, 63.4ms
# Speed: 0.0ms preprocess, 63.4ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 6 Cars, 1 Cng, 4 Covered-Vans, 63.2ms
# Speed: 13.1ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 2 Cngs, 3 Covered-Vans, 47.9ms
# Speed: 2.5ms preprocess, 47.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 4 Covered-Vans, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 2 Cngs, 4 Covered-Vans, 48.7ms
# Speed: 2.2ms preprocess, 48.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 3 Cngs, 4 Covered-Vans, 47.9ms
# Speed: 15.6ms preprocess, 47.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 3 Covered-Vans, 55.7ms
# Speed: 15.6ms preprocess, 55.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 3 Covered-Vans, 1 Person, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 3 Covered-Vans, 1 Person, 103.8ms
# Speed: 0.0ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 3 Covered-Vans, 1 Person, 65.3ms
# Speed: 2.9ms preprocess, 65.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 3 Covered-Vans, 1 Person, 99.1ms
# Speed: 0.0ms preprocess, 99.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 2 Covered-Vans, 1 Person, 98.2ms
# Speed: 0.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 2 Covered-Vans, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 3 Cngs, 2 Covered-Vans, 96.8ms
# Speed: 0.0ms preprocess, 96.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 4 Cngs, 2 Covered-Vans, 72.0ms
# Speed: 15.7ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Covered-Van, 1 Person, 71.2ms
# Speed: 13.0ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 2 Covered-Vans, 63.5ms
# Speed: 15.9ms preprocess, 63.5ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Covered-Van, 1 Person, 68.0ms
# Speed: 8.9ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 3 Cngs, 1 Covered-Van, 81.6ms
# Speed: 0.0ms preprocess, 81.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 65.9ms
# Speed: 0.0ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Covered-Van, 79.1ms
# Speed: 11.4ms preprocess, 79.1ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 1 Covered-Van, 1 Motor-Cycle, 64.8ms
# Speed: 0.0ms preprocess, 64.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Cng, 1 Covered-Van, 71.2ms
# Speed: 0.0ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Covered-Van, 69.2ms
# Speed: 0.0ms preprocess, 69.2ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Covered-Van, 64.1ms
# Speed: 0.0ms preprocess, 64.1ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Cng, 1 Covered-Van, 1 Person, 52.6ms
# Speed: 0.0ms preprocess, 52.6ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Cng, 1 Covered-Van, 1 Person, 63.3ms
# Speed: 10.7ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 68.5ms
# Speed: 0.5ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Covered-Van, 1 Motor-Cycle, 51.1ms
# Speed: 0.0ms preprocess, 51.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 89.8ms
# Speed: 0.0ms preprocess, 89.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 1 Covered-Van, 79.2ms
# Speed: 11.0ms preprocess, 79.2ms inference, 15.5ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 47.8ms
# Speed: 1.2ms preprocess, 47.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Motor-Cycle, 102.7ms
# Speed: 0.0ms preprocess, 102.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 52.2ms
# Speed: 3.4ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Motor-Cycle, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 1 Motor-Cycle, 79.1ms
# Speed: 0.0ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 94.1ms
# Speed: 6.9ms preprocess, 94.1ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Motor-Cycle, 109.4ms
# Speed: 0.0ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 1 Motor-Cycle, 62.5ms
# Speed: 15.6ms preprocess, 62.5ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Motor-Cycle, 79.1ms
# Speed: 0.0ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 5 Cars, 1 Cng, 1 Motor-Cycle, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Motor-Cycle, 46.9ms
# Speed: 13.6ms preprocess, 46.9ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Motor-Cycle, 63.8ms
# Speed: 7.8ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Motor-Cycle, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Motor-Cycle, 65.3ms
# Speed: 1.8ms preprocess, 65.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 2 Cars, 1 Cng, 1 Motor-Cycle, 78.2ms
# Speed: 0.0ms preprocess, 78.2ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Motor-Cycle, 47.6ms
# Speed: 0.0ms preprocess, 47.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Motor-Cycle, 87.6ms
# Speed: 0.0ms preprocess, 87.6ms inference, 1.7ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 2 Cngs, 1 Motor-Cycle, 79.7ms
# Speed: 4.8ms preprocess, 79.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 2 Cngs, 1 Motor-Cycle, 63.6ms
# Speed: 6.5ms preprocess, 63.6ms inference, 16.2ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Motor-Cycle, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Motor-Cycle, 47.5ms
# Speed: 0.0ms preprocess, 47.5ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 4 Cars, 1 Cng, 1 Motor-Cycle, 66.5ms
# Speed: 16.3ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 288)
#
# 0: 192x288 3 Cars, 1 Cng, 1 Person, 49.7ms
# Speed: 13.3ms preprocess, 49.7ms inference, 15.6ms postprocess per image at shape (1, 3, 192, 288)

# %%
import torch
from ultralytics import YOLO

def train_model():
    # Load the YOLOv11 model
    model = YOLO("yolo11m.pt").to("cuda" if torch.cuda.is_available() else "cpu")

    # Confirm that the model is on GPU
    if next(model.parameters()).is_cuda:
        print("Model is running on GPU.")
    else:
        print("Model is running on CPU.")
    

    # Train the model with additional options
    train_results = model.train(
        data="E:/Ml_Course/pythonProject_object/i2-9/dataset.yaml",  # Path to your dataset YAML
        epochs=40,
        imgsz=280,                # Image size for training
        device="cuda",                 # Set to "cuda" for GPU or "cpu" for CPU
    )

    # Return training results for analysis
    return train_results

# Run the training function
train_model()
